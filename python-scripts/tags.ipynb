# %%
import pandas as pd

smallRecipes = pd.read_csv('../src/recipesDB/Small_Recipes.csv')

# %%
def returnSteps(smallRecipe):
    smallRecipe = pd.DataFrame(smallRecipe.set_index('id')['tags'])
    smallRecipe["tags"] = smallRecipe["tags"].str.replace("[", '')
    smallRecipe["tags"] = smallRecipe["tags"].str.replace("']", '')
    smallRecipe = smallRecipe.tags.str.split("', '",expand=True)
    smallRecipe[0] = smallRecipe[0].str.replace("'", '')
    return smallRecipe
allSteps = returnSteps(smallRecipes)
tags = []
for i in range(len(allSteps.columns)):
    tags = tags + list(allSteps.iloc[:,i].unique())
tags = set(tags)
while '' in tags:
    tags.remove('')
while None in tags:
    tags.remove(None)
tags
# Out:
# C:\Users\sushi\AppData\Local\Temp\ipykernel_788\3236511081.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   smallRecipe["tags"] = smallRecipe["tags"].str.replace("[", '')
# C:\Users\sushi\AppData\Local\Temp\ipykernel_788\3236511081.py:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   smallRecipe["tags"] = smallRecipe["tags"].str.replace("']", '')
# {'1-day-or-more',
#  '15-minutes-or-less',
#  '3-steps-or-less',
#  '30-minutes-or-less',
#  '4-hours-or-less',
#  '5-ingredients-or-less',
#  '60-minutes-or-less',
#  'african',
#  'american',
#  'amish-mennonite',
#  'appetizers',
#  'apples',
#  'argentine',
#  'asian',
#  'asparagus',
#  'australian',
#  'bacon',
#  'baja',
#  'baking',
#  'bananas',
#  'bar-cookies',
#  'barbecue',
#  'beans',
#  'beef',
#  'beef-ribs',
#  'beef-sausage',
#  'beginner-cook',
#  'belgian',
#  'berries',
#  'beverages',
#  'biscotti',
#  'bisques-cream-soups',
#  'black-beans',
#  'blueberries',
#  'brazilian',
#  'bread-machine',
#  'breads',
#  'breakfast',
#  'british-columbian',
#  'broccoli',
#  'broil',
#  'brown-bag',
#  'brown-rice',
#  'brownies',
#  'brunch',
#  'burgers',
#  'cajun',
#  'cake-fillings-and-frostings',
#  'cakes',
#  'californian',
#  'camping',
#  'canadian',
#  'candy',
#  'canning',
#  'caribbean',
#  'carrots',
#  'casseroles',
#  'catfish',
#  'cauliflower',
#  'celebrity',
#  'central-american',
#  'chard',
#  'cheese',
#  'cheesecake',
#  'cherries',
#  'chick-peas-garbanzos',
#  'chicken',
#  'chicken-breasts',
#  'chicken-livers',
#  'chicken-thighs-legs',
#  'chilean',
#  'chili',
#  'chinese',
#  'chocolate',
#  'chocolate-chip-cookies',
#  'chowders',
#  'christmas',
#  'cinco-de-mayo',
#  'citrus',
#  'clams',
#  'clear-soups',
#  'cobblers-and-crisps',
#  'cocktails',
#  'coconut',
#  'cod',
#  'coffee-cakes',
#  'collard-greens',
#  'colombian',
#  'comfort-food',
#  'condiments-etc',
#  'cookies-and-brownies',
#  'cooking-mixes',
#  'copycat',
#  'corn',
#  'costa-rican',
#  'course',
#  'crab',
#  'creole',
#  'crock-pot-slow-cooker',
#  'crusts-pastry-dough-2',
#  'cuban',
#  'cuisine',
#  'cupcakes',
#  'curries',
#  'czech',
#  'dairy-free',
#  'deep-fry',
#  'deer',
#  'desserts',
#  'diabetic',
#  'dietary',
#  'dinner-party',
#  'dips',
#  'drop-cookies',
#  'easter',
#  'easy',
#  'ecuadorean',
#  'egg-free',
#  'eggs',
#  'eggs-dairy',
#  'elbow-macaroni',
#  'elk',
#  'english',
#  'equipment',
#  'european',
#  'fall',
#  'filipino',
#  'finger-food',
#  'fish',
#  'flat-shapes',
#  'food-processor-blender',
#  'for-1-or-2',
#  'for-large-groups',
#  'free-of-something',
#  'freezer',
#  'french',
#  'freshwater-fish',
#  'from-scratch',
#  'frozen-desserts',
#  'fruit',
#  'fudge',
#  'garnishes',
#  'gelatin',
#  'german',
#  'gifts',
#  'gluten-free',
#  'grains',
#  'granola-and-porridge',
#  'grapes',
#  'greek',
#  'green-yellow-beans',
#  'greens',
#  'grilling',
#  'ground-beef',
#  'guatemalan',
#  'gumbo',
#  'halibut',
#  'halloween',
#  'ham',
#  'hand-formed-cookies',
#  'hanukkah',
#  'hawaiian',
#  'healthy',
#  'healthy-2',
#  'heirloom-historical',
#  'herb-and-spice-mixes',
#  'hidden-valley-ranch',
#  'high-calcium',
#  'high-fiber',
#  'high-in-something',
#  'high-protein',
#  'holiday-event',
#  'honduran',
#  'independence-day',
#  'indian',
#  'indonesian',
#  'inexpensive',
#  'infant-baby-friendly',
#  'iranian-persian',
#  'irish',
#  'italian',
#  'jams-and-preserves',
#  'japanese',
#  'jellies',
#  'jewish-ashkenazi',
#  'jewish-sephardi',
#  'kid-friendly',
#  'korean',
#  'kosher',
#  'kwanzaa',
#  'lactose',
#  'lamb-sheep',
#  'lasagna',
#  'lebanese',
#  'lemon',
#  'lentils',
#  'lettuces',
#  'lime',
#  'lobster',
#  'long-grain-rice',
#  'low-calorie',
#  'low-carb',
#  'low-cholesterol',
#  'low-fat',
#  'low-in-something',
#  'low-protein',
#  'low-saturated-fat',
#  'low-sodium',
#  'lunch',
#  'main-dish',
#  'main-ingredient',
#  'malaysian',
#  'mango',
#  'manicotti',
#  'mardi-gras-carnival',
#  'marinades-and-rubs',
#  'mashed-potatoes',
#  'meat',
#  'meatloaf',
#  'medium-grain-rice',
#  'melons',
#  'mexican',
#  'microwave',
#  'middle-eastern',
#  'midwestern',
#  'mixer',
#  'moose',
#  'moroccan',
#  'muffins',
#  'mushrooms',
#  'new-years',
#  'new-zealand',
#  'no-cook',
#  'no-shell-fish',
#  'north-american',
#  'northeastern-united-states',
#  'norwegian',
#  'novelty',
#  'number-of-servings',
#  'nut-free',
#  'nuts',
#  'oamc-freezer-make-ahead',
#  'occasion',
#  'omelets-and-frittatas',
#  'one-dish-meal',
#  'onions',
#  'ontario',
#  'oranges',
#  'oven',
#  'pacific-northwest',
#  'pakistani',
#  'pancakes-and-waffles',
#  'passover',
#  'pasta',
#  'pasta-rice-and-grains',
#  'pasta-shells',
#  'peaches',
#  'peanut-butter',
#  'pears',
#  'penne',
#  'pennsylvania-dutch',
#  'peppers',
#  'peruvian',
#  'picnic',
#  'pies',
#  'pies-and-tarts',
#  'pineapple',
#  'pitted-fruit',
#  'pizza',
#  'plums',
#  'polish',
#  'pork',
#  'pork-chops',
#  'pork-loins',
#  'pork-ribs',
#  'pork-sausage',
#  'portuguese',
#  'potatoes',
#  'potluck',
#  'poultry',
#  'preparation',
#  'presentation',
#  'pressure-cooker',
#  'puddings-and-mousses',
#  'punch',
#  'quick-breads',
#  'ramadan',
#  'raspberries',
#  'ravioli-tortellini',
#  'refrigerator',
#  'reynolds-wrap',
#  'rice',
#  'roast',
#  'roast-beef',
#  'rolled-cookies',
#  'rolls-biscuits',
#  'romantic',
#  'rosh-hashana',
#  'rosh-hashanah',
#  'russian',
#  'salad-dressings',
#  'salads',
#  'salmon',
#  'salsas',
#  'saltwater-fish',
#  'sandwiches',
#  'sauces',
#  'savory',
#  'savory-pies',
#  'savory-sauces',
#  'scallops',
#  'scandinavian',
#  'scones',
#  'scottish',
#  'seafood',
#  'seasonal',
#  'served-cold',
#  'served-hot',
#  'shakes',
#  'shellfish',
#  'short-grain-rice',
#  'shrimp',
#  'side-dishes',
#  'simply-potatoes',
#  'simply-potatoes2',
#  'small-appliance',
#  'smoker',
#  'smoothies',
#  'snacks',
#  'soul',
#  'soups-stews',
#  'sourdough',
#  'south-african',
#  'south-american',
#  'south-west-pacific',
#  'southern-united-states',
#  'southwestern-united-states',
#  'soy-tofu',
#  'spaghetti',
#  'spanish',
#  'spicy',
#  'spinach',
#  'spreads',
#  'spring',
#  'squash',
#  'st-patricks-day',
#  'steak',
#  'steam',
#  'stews',
#  'stir-fry',
#  'stocks',
#  'stove-top',
#  'strawberries',
#  'stuffings-dressings',
#  'summer',
#  'super-bowl',
#  'superbowl',
#  'swedish',
#  'sweet',
#  'sweet-sauces',
#  'swiss',
#  'szechuan',
#  'taste-mood',
#  'technique',
#  'tex-mex',
#  'thai',
#  'thanksgiving',
#  'tilapia',
#  'time-to-make',
#  'to-go',
#  'toddler-friendly',
#  'tomatoes',
#  'tropical-fruit',
#  'trout',
#  'tuna',
#  'turkey',
#  'turkey-breasts',
#  'turkey-burgers',
#  'turkish',
#  'valentines-day',
#  'veal',
#  'vegan',
#  'vegetables',
#  'vegetarian',
#  'venezuelan',
#  'very-low-carbs',
#  'vietnamese',
#  'water-bath',
#  'wedding',
#  'weeknight',
#  'welsh',
#  'white-rice',
#  'whole-chicken',
#  'whole-turkey',
#  'wild-game',
#  'wings',
#  'winter',
#  'yams-sweet-potatoes',
#  'yeast',
#  'zucchini'}
